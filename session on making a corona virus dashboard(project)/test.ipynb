# %%
import numpy as np
import pandas as pd

pateints=pd.read_csv(r"IndividualDetails.csv")
total=pateints.shape[0]
active=pateints.query("current_status=='Hospitalized'").shape[0]
recovered=pateints.query("current_status=='Recovered'").shape[0]
death=pateints.query("current_status=='Deceased'").shape[0]
# Out:
# 30

# %%
pateints.sample(20)
# Out:
#         id government_id diagnosed_date  age gender  detected_city  \
# 62      62           NaN     10/03/2020   85      M         Jaipur
# 4607  4607           NaN     06/04/2020  NaN    NaN            NaN
# 2577  2577           NaN     03/04/2020  NaN    NaN            NaN
# 581    581           NaN     25/03/2020  NaN    NaN         Sangli
# 7172  7173           NaN     10/04/2020  NaN    NaN            NaN
# 6083  6084           NaN     09/04/2020  NaN    NaN            NaN
# 1796  1796       TN-P212     01/04/2020   60      M           Bodi
# 167    167        TS-P12     18/03/2020  NaN    NaN      Hyderabad
# 2918  2918           NaN     03/04/2020  NaN    NaN            NaN
# 1009  1009           NaN     28/03/2020  NaN    NaN            NaN
# 1025  1025           NaN     28/03/2020   48      M            NaN
# 6157  6158           NaN     09/04/2020  NaN    NaN            NaN
# 194    194           NaN     19/03/2020  NaN      F         Jaipur
# 1543  1543       TN-P109     31/03/2020  NaN      M            NaN
# 396    396         AP-P6     22/03/2020   49      F  Visakhapatnam
# 4228  4228           NaN     05/04/2020  NaN    NaN            NaN
# 3369  3369           NaN     04/04/2020  NaN    NaN            NaN
# 6342  6343       TN-P792     09/04/2020  NaN      M            NaN
# 8        8           NaN     04/03/2020   55    NaN       Gurugram
# 5022  5023           NaN     07/04/2020  NaN    NaN            NaN
#
#      detected_district  detected_state nationality current_status  \
# 62              Jaipur       Rajasthan       India      Recovered
# 4607            Mumbai     Maharashtra         NaN   Hospitalized
# 2577     Visakhapatnam  Andhra Pradesh         NaN   Hospitalized
# 581             Sangli     Maharashtra         NaN   Hospitalized
# 7172               NaN           Delhi         NaN   Hospitalized
# 6083            Mumbai     Maharashtra         NaN   Hospitalized
# 1796             Theni      Tamil Nadu         NaN   Hospitalized
# 167          Hyderabad       Telangana   Indonesia   Hospitalized
# 2918               NaN       Telangana         NaN   Hospitalized
# 1009               NaN       Telangana         NaN   Hospitalized
# 1025            Indore  Madhya Pradesh         NaN   Hospitalized
# 6157            Mumbai     Maharashtra         NaN   Hospitalized
# 194             Jaipur       Rajasthan       India   Hospitalized
# 1543          Namakkal      Tamil Nadu         NaN   Hospitalized
# 396      Visakhapatnam  Andhra Pradesh       India   Hospitalized
# 4228         Hyderabad       Telangana         NaN   Hospitalized
# 3369        Mahrajganj   Uttar Pradesh         NaN   Hospitalized
# 6342          Namakkal      Tamil Nadu         NaN   Hospitalized
# 8            Italians*         Haryana       Italy      Recovered
# 5022               Nuh         Haryana         NaN   Hospitalized
#
#      status_change_date                                              notes
# 62           10/03/2020                               Travelled from Dubai
# 4607         06/04/2020                                    Details awaited
# 2577         03/04/2020                                                NaN
# 581          25/03/2020                                    Details awaited
# 7172         10/04/2020                                    Details awaited
# 6083         09/04/2020                                    Details awaited
# 1796         01/04/2020                                 Travelled to Delhi
# 167          18/03/2020                                         Indonesian
# 2918         03/04/2020                                    Details awaited
# 1009         28/03/2020                                    Details awaited
# 1025         28/03/2020  contacts of earlier positive cases of #COVID19...
# 6157         09/04/2020                                    Details awaited
# 194          19/03/2020  Travelled from Spain via Dubai - New Delhi on ...
# 1543         31/03/2020                                 Travelled to Delhi
# 396          22/03/2020                  Patient's husband tested positive
# 4228         05/04/2020                                    Details Awaited
# 3369         04/04/2020                                 Travelled to Delhi
# 6342         09/04/2020                                    Details awaited
# 8            29/03/2020                               Travelled from Italy
# 5022         07/04/2020                                    Details awaited
